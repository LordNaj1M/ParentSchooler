# %%
import pandas as pd

data = pd.read_csv('journal_scrape_with_keywords_new.csv')

# %%
data
# Out:
#      Unnamed: 0                                   pdf_article_link  \
# 0             0  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 1             1  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 2             2  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 3             3  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 4             4  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# ..          ...                                                ...
# 335         335  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 336         336  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 337         337  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 338         338  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 339         339  https://jurnal.ipb.ac.id/index.php/jikk/articl...
#
#                                           article_name  \
# 0    PENGARUH TIPOLOGI KELUARGA DAN LINGKUNGAN RAMA...
# 1    HARAPAN ORANG TUA, EFIKASI DIRI AKADEMIK, DAN ...
# 2    PERAN KELUARGA DAN TOLERANSI AMBIGUITAS PADA E...
# 3    THE ROLE OF MORALLY RELEVANT THEORY OF MIND AN...
# 4    ANALISIS RIWAYAT PENGASUHAN PADA TINGKAT POSTT...
# ..                                                 ...
# 335  ANALISIS BEBAN KERJA IBU DAN PENGASUHAN ANAK U...
# 336  PERAN STIMULASI ORANGTUA TERHADAP PERKEMBANGAN...
# 337  ANALISIS MANFAAT DAN KEPUASAN PESERTA WANITA P...
# 338              PERILAKU KONSUMSI SUSU PADA IBU HAMIL
# 339  FAKTOR-FAKTOR PENENTU PENGAMBILAN KEPUTUSAN PE...
#
#                                               abstract  \
# 0    Keluarga dan lingkungan keluarga yang mendukun...
# 1    Fenomena tingginya angka putus sekolah pada je...
# 2    Pengaruh keluarga serta toleransi ambiguitas b...
# 3    Prosocial lying refers to deceptive behavior p...
# 4    Pandemi Covid-19 memberikan ancaman serius bag...
# ..                                                 ...
# 335  The objective of study was to study mother wor...
# 336  Parents have an important role in childcare. N...
# 337  The objectives of the study were: to identify ...
# 338  Pregnant woman with her physiological state is...
# 339  In determining major choosing, students as con...
#
#                                               citation  \
# 0    SalamahA., SunartiE., & Eva RianyY. (2023). PE...
# 1    NurdiniG. A., & Neti Hernawati. (2023). HARAPA...
# 2    DjudiyahD., UningowatiD. W., & SyakarofathN. A...
# 3    KuntoroI. A., Nabila Aulia Herman, & Inge Uli ...
# 4    MustaminS. N., Dwi Hastuti, & Yulina Eva Riany...
# ..                                                 ...
# 335  YulianisD., MartiantoD., & HastutiD. (2008). A...
# 336  BriawanD., & HerawatiT. (2008). PERAN STIMULAS...
# 337  JuliantiE. D., HartoyoH., & GuhardjaS. (2008)....
# 338  SariM. N., & RetnaningsihR. (2008). PERILAKU K...
# 339  SimanjuntakM., & JohanI. R. (2008). FAKTOR-FAK...
#
#                                      keywords  \
# 0    ['keluarga', 'tipologi', 'meningkatkan']
# 1            ['akademik', 'siswa', 'harapan']
# 2         ['mahasiswa', 'penelitian', 'diri']
# 3             ['lying', 'prosocial', 'motom']
# 4          ['responden', 'ptg', 'pengasuhan']
# ..                                        ...
# 335             ['mothers', 'spent', 'hours']
# 336    ['stimulation', 'children', 'parents']
# 337          ['center', 'fitness', 'joining']
# 338        ['milk', 'samples', 'correlation']
# 339       ['factors', 'students', 'choosing']
#
#                                         keywords_score
# 0    [0.26354655131309174, 0.1340543982301991, 0.11...
# 1    [0.18207556319360202, 0.1500129552644624, 0.10...
# 2    [0.12073149312443121, 0.11764117507755378, 0.1...
# 3    [0.09782351503317968, 0.09782351503317968, 0.0...
# 4    [0.1026234984901215, 0.09602219189404047, 0.09...
# ..                                                 ...
# 335  [0.10543128492081938, 0.10401512217468553, 0.0...
# 336  [0.12122953309527922, 0.10685496767686722, 0.0...
# 337  [0.11710853251190759, 0.11710853251190759, 0.1...
# 338  [0.1662498252861236, 0.11842394405443306, 0.07...
# 339  [0.2441825406212599, 0.2441825406212599, 0.176...
#
# [340 rows x 7 columns]

# %%
import langdetect
from langdetect import detect

# %%
def detect_language(abstract) :
    language = detect(abstract)
    
    if language == 'id' :
        language = 'Indonesia'
    elif language == 'en' :
        language = 'English'
    else :
        language = 'Others'
        
    return language

# %%
data['language'] = data['abstract'].apply(lambda abstract : detect_language(str(abstract)))

# %%
data
# Out:
#      Unnamed: 0                                   pdf_article_link  \
# 0             0  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 1             1  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 2             2  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 3             3  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 4             4  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# ..          ...                                                ...
# 335         335  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 336         336  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 337         337  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 338         338  https://jurnal.ipb.ac.id/index.php/jikk/articl...
# 339         339  https://jurnal.ipb.ac.id/index.php/jikk/articl...
#
#                                           article_name  \
# 0    PENGARUH TIPOLOGI KELUARGA DAN LINGKUNGAN RAMA...
# 1    HARAPAN ORANG TUA, EFIKASI DIRI AKADEMIK, DAN ...
# 2    PERAN KELUARGA DAN TOLERANSI AMBIGUITAS PADA E...
# 3    THE ROLE OF MORALLY RELEVANT THEORY OF MIND AN...
# 4    ANALISIS RIWAYAT PENGASUHAN PADA TINGKAT POSTT...
# ..                                                 ...
# 335  ANALISIS BEBAN KERJA IBU DAN PENGASUHAN ANAK U...
# 336  PERAN STIMULASI ORANGTUA TERHADAP PERKEMBANGAN...
# 337  ANALISIS MANFAAT DAN KEPUASAN PESERTA WANITA P...
# 338              PERILAKU KONSUMSI SUSU PADA IBU HAMIL
# 339  FAKTOR-FAKTOR PENENTU PENGAMBILAN KEPUTUSAN PE...
#
#                                               abstract  \
# 0    Keluarga dan lingkungan keluarga yang mendukun...
# 1    Fenomena tingginya angka putus sekolah pada je...
# 2    Pengaruh keluarga serta toleransi ambiguitas b...
# 3    Prosocial lying refers to deceptive behavior p...
# 4    Pandemi Covid-19 memberikan ancaman serius bag...
# ..                                                 ...
# 335  The objective of study was to study mother wor...
# 336  Parents have an important role in childcare. N...
# 337  The objectives of the study were: to identify ...
# 338  Pregnant woman with her physiological state is...
# 339  In determining major choosing, students as con...
#
#                                               citation  \
# 0    SalamahA., SunartiE., & Eva RianyY. (2023). PE...
# 1    NurdiniG. A., & Neti Hernawati. (2023). HARAPA...
# 2    DjudiyahD., UningowatiD. W., & SyakarofathN. A...
# 3    KuntoroI. A., Nabila Aulia Herman, & Inge Uli ...
# 4    MustaminS. N., Dwi Hastuti, & Yulina Eva Riany...
# ..                                                 ...
# 335  YulianisD., MartiantoD., & HastutiD. (2008). A...
# 336  BriawanD., & HerawatiT. (2008). PERAN STIMULAS...
# 337  JuliantiE. D., HartoyoH., & GuhardjaS. (2008)....
# 338  SariM. N., & RetnaningsihR. (2008). PERILAKU K...
# 339  SimanjuntakM., & JohanI. R. (2008). FAKTOR-FAK...
#
#                                      keywords  \
# 0    ['keluarga', 'tipologi', 'meningkatkan']
# 1            ['akademik', 'siswa', 'harapan']
# 2         ['mahasiswa', 'penelitian', 'diri']
# 3             ['lying', 'prosocial', 'motom']
# 4          ['responden', 'ptg', 'pengasuhan']
# ..                                        ...
# 335             ['mothers', 'spent', 'hours']
# 336    ['stimulation', 'children', 'parents']
# 337          ['center', 'fitness', 'joining']
# 338        ['milk', 'samples', 'correlation']
# 339       ['factors', 'students', 'choosing']
#
#                                         keywords_score   language
# 0    [0.26354655131309174, 0.1340543982301991, 0.11...  Indonesia
# 1    [0.18207556319360202, 0.1500129552644624, 0.10...  Indonesia
# 2    [0.12073149312443121, 0.11764117507755378, 0.1...  Indonesia
# 3    [0.09782351503317968, 0.09782351503317968, 0.0...    English
# 4    [0.1026234984901215, 0.09602219189404047, 0.09...  Indonesia
# ..                                                 ...        ...
# 335  [0.10543128492081938, 0.10401512217468553, 0.0...    English
# 336  [0.12122953309527922, 0.10685496767686722, 0.0...    English
# 337  [0.11710853251190759, 0.11710853251190759, 0.1...    English
# 338  [0.1662498252861236, 0.11842394405443306, 0.07...    English
# 339  [0.2441825406212599, 0.2441825406212599, 0.176...    English
#
# [340 rows x 8 columns]

# %%
data.to_csv('complete_journal_data_new.csv', index = False)
